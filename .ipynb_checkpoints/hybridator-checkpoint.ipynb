# %%
import numpy as np 
import matplotlib.pyplot as plt
from load_data import *
from functions import *
from hybridate import *

# %%
# !nvidia-smi
# Out:
# Wed Jul 10 09:57:53 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.29.05    Driver Version: 495.29.05    CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-PCI...  On   | 00000000:25:00.0 Off |                    0 |
# | N/A   30C    P0    37W / 250W |  14505MiB / 40536MiB |     15%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    753639      C   ...vs/montenvtest/bin/python    13119MiB |
# |    0   N/A  N/A    791000      C   ...nda/envs/essai/bin/python     1381MiB |
# +-----------------------------------------------------------------------------+

# %%
# TF_CPP_MIN_LOG_LEVEL=10
jax.devices()
# Out:
# [gpu(id=0)]

# %%
no_scales = 2
start = 1
end = 11
file_nos = np.arange(start, end)
fig, axs = plt.subplots(2, no_scales + 3, figsize=(22, 10))
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16

moments_target_full = np.zeros((len(file_nos), 5))
moments_target_starlet= np.zeros((no_scales+1, len(file_nos), 5))
moments_hybridated_full = np.zeros((len(file_nos), 5))
moments_hybridated_starlet= np.zeros((no_scales+1, len(file_nos), 5))

for i, file_no in enumerate(start+file_nos+1):
    print(f"Iteration {i}", end='\r')
    results = hybridate(redshift=1.5, file_number=10,model_name="model_one",ell_min=0, ell_max=24200, cls_bins=50, nscales=no_scales, pdf_bins=150, no_iterations=50, plot=False)
    target = results["target"]
    angle = results["angle"]
    nscales = results["nscales"]
    ell_min = results["ell_min"]
    ell_max = results["ell_max"]
    cls_bins = results["cls_bins"]
    pdf_bins = results["pdf_bins"]
    target_starlet_cls = results["target_starlet_cls"]
    target_ell_edges = results["target_ell_edges"]
    target_ell_bins = results["target_ell_bins"]
    target_cls_values = results["target_cls_values"]
    target_starlet = results["target_starlet"]
    target_edges = results["target_edges"]
    target_bin_centers = results["target_bin_centers"]
    target_pdf = results["target_pdf"]
    target_cdf = results["target_cdf"]
    target_starlet_edges = results["target_starlet_edges"]
    target_starlet_bin_centers = results["target_starlet_bin_centers"]
    target_starlet_pdf = results["target_starlet_pdf"]
    target_starlet_cdf = results["target_starlet_cdf"]
    target_starlet_cls = results["target_starlet_cls"]
    corrected_full_map = results["hybridated_map"]
            
    corrected_ell_edges, corrected_ell_bins, corrected_cls_values = calculate_Cls(corrected_full_map, angle, ell_min, ell_max, cls_bins)
    corrected_edges, corrected_bin_centers, corrected_pdf = calculate_pdf(corrected_full_map, target_edges)

    corrected_starlet = starlet2d(corrected_full_map, nscales)
    corrected_starlet_edges = []
    corrected_starlet_bin_centers = []
    corrected_starlet_pdf = []
    corrected_starlet_cls = []
    # moments_target_full[i-1] = get_moments(target_bin_centers, target_pdf)
    moments_hybridated_full[i-1] = get_moments(corrected_bin_centers, corrected_pdf)
    
    for scale in range(nscales + 1):
        edges, bin_centers, counts = calculate_pdf(corrected_starlet[scale], target_starlet_edges[scale])
        corrected_starlet_edges.append(edges)
        corrected_starlet_bin_centers.append(bin_centers)
        corrected_starlet_pdf.append(counts)
        corrected_starlet_cls.append(calculate_Cls(corrected_starlet[scale], angle, ell_min, ell_max, cls_bins)[2])
        moments_hybridated_starlet[scale, i-1] = get_moments(bin_centers, counts)
        # moments_target_starlet[scale, i-1] = get_moments(target_starlet_bin_centers[scale], target_starlet_pdf[scale])
    
    axs[0,0].loglog(target_ell_bins, target_cls_values, label="Target Cls", c="r")
    axs[0,0].set_ylabel("Cls Values", fontsize=18)
    axs[0,0].set_title("Cls", fontsize=20)
    axs[0,1].plot(target_bin_centers, target_pdf, label="Target PDF", c="r")
    axs[0,1].set_ylabel("PDF Values", fontsize=18)
    axs[0,1].set_xlabel(r"$\kappa$", fontsize=18)
    axs[0,1].set_title("PDF", fontsize=20)

    for scale in range(nscales + 1):
        axs[0,2+scale].plot(target_starlet_bin_centers[scale], target_starlet_pdf[scale], label="target", c="r")
        axs[0,2+scale].plot(corrected_starlet_bin_centers[scale], corrected_starlet_pdf[scale], label=f'Emulated', ls=":")
        axs[0,2+scale].set_title(f"Scale {scale}", fontsize=20)
        # axs[0,2+scale].legend(fontsize=12)
        axs[0,2+scale].set_xlabel(r"$\kappa$", fontsize=18)    
        axs[1,2+scale].plot(corrected_starlet_bin_centers[scale], (corrected_starlet_pdf[scale] / target_starlet_pdf[scale]) - 1, label="emulated", ls=":")
        axs[1,2+scale].set_ylabel("Residual", fontsize=18)
        axs[1,2+scale].set_xlabel(r"$\kappa$", fontsize=18)    
        # axs[1,2+scale].legend(fontsize=12)
        axs[1,2+scale].set_xlim(np.mean(target_starlet[scale]) - 2.5 * np.std(target_starlet[scale]), np.mean(target_starlet[scale]) + 2.5 * np.std(target_starlet[scale]))
        axs[1,2+scale].set_ylim(-0.5, 0.5)
        
    axs[0,0].loglog(corrected_ell_bins, corrected_cls_values, label="emulated", ls=":")
    axs[1,0].plot(corrected_ell_bins, (corrected_cls_values - target_cls_values)/target_cls_values, ls=":", label="emulated")
    axs[1,0].set_xlim(0, 24000)

    # Plot PDF
    axs[0,1].plot(corrected_bin_centers, corrected_pdf, label="emulated", ls=":")
    axs[0,1].set_ylabel("Residual Cls", fontsize=18)
    axs[1,1].plot(corrected_bin_centers, (corrected_pdf / target_pdf) - 1, label="emulated", ls=":")
    axs[1,1].set_ylabel("Residual PDF", fontsize=18)
    axs[1,1].set_ylim(-0.5, 0.5)
    axs[1,1].set_xlim(np.mean(target) - 2.5 * np.std(target), np.mean(target) + 2.5 * np.std(target))
    # axs[1,1].legend(fontsize=12) 
    plt.tight_layout()
    
    data, angle_ = load_data_mnu(redshift=1.5, file_number=file_no, model_name="model_one")

    target_results = get_target_values(data, angle_, ell_min, ell_max, cls_bins, nscales, pdf_bins)

    target = target_results["target"]
    angle = target_results["angle"]
    nscales = target_results["nscales"]
    ell_min = target_results["ell_min"]
    ell_max = target_results["ell_max"]
    cls_bins = target_results["cls_bins"]
    pdf_bins = target_results["pdf_bins"]
    target_starlet_cls = target_results["target_starlet_cls"]
    target_ell_edges = target_results["target_ell_edges"]
    target_ell_bins = target_results["target_ell_bins"]
    target_cls_values = target_results["target_cls_values"]
    target_starlet = target_results["target_starlet"]
    target_edges = target_results["target_edges"]
    target_bin_centers = target_results["target_bin_centers"]
    target_pdf = target_results["target_pdf"]
    target_cdf = target_results["target_cdf"]
    target_starlet_edges = target_results["target_starlet_edges"]
    target_starlet_bin_centers = target_results["target_starlet_bin_centers"]
    target_starlet_pdf = target_results["target_starlet_pdf"]
    target_starlet_cdf = target_results["target_starlet_cdf"]
    moments_target_full[i-1] = get_moments(target_bin_centers, target_pdf)
    for scale in range(nscales + 1):
        moments_target_starlet[scale, i-1] = get_moments(target_starlet_bin_centers[scale], target_starlet_pdf[scale])
# Out:
# Iteration 0
# 2024-07-10 10:15:57.167875: E external/xla/xla/stream_executor/cuda/cuda_dnn.cc:427] Loaded runtime CuDNN library: 8.3.1 but source was compiled with: 8.6.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[2], line 16
#      14 for i, file_no in enumerate(start+file_nos+1):
#      15     print(f"Iteration {i}", end='\r')
# ---> 16     results = hybridate(redshift=1.5, file_number=10,model_name="model_one",ell_min=0, ell_max=24200, cls_bins=50, nscales=no_scales, pdf_bins=150, no_iterations=50, plot=False)
#      17     target = results["target"]
#      18     angle = results["angle"]
#
# File /feynman/work/dap/lcs/vt272285/Hybridator/hybridate.py:10, in hybridate(redshift, file_number, model_name, ell_min, ell_max, cls_bins, nscales, pdf_bins, no_iterations, plot)
#       8 data, angle_ = load_data_mnu(redshift, file_number, model_name)
#       9 # data, angle_ = load_data(file_no=75)
# ---> 10 target_results = get_target_values(data, angle_, ell_min, ell_max, cls_bins, nscales, pdf_bins)
#      12 target = target_results["target"]
#      13 angle = target_results["angle"]
#
# File /feynman/work/dap/lcs/vt272285/Hybridator/functions.py:210, in get_target_values(data, angle, ell_min, ell_max, cls_bins, nscales, pdf_bins)
#     208 target = data - np.mean(data)
#     209 # print("the mean of target is: ", np.mean(target))
# --> 210 target_ell_edges, target_ell_bins, target_cls_values = calculate_Cls(target, angle_deg, ell_min, ell_max, cls_bins)
#     211 target_starlet = starlet_decompose(target, nscales)
#     212 target_edges, target_bin_centers, target_pdf = calculate_pdf(target, pdf_bins)
#
#     [... skipping hidden 14 frame]
#
# File ~/.conda/envs/general/lib/python3.8/site-packages/jax/_src/dispatch.py:465, in backend_compile(backend, module, options, host_callbacks)
#     460   return backend.compile(built_c, compile_options=options,
#     461                          host_callbacks=host_callbacks)
#     462 # Some backends don't have `host_callbacks` option yet
#     463 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     464 # to take in `host_callbacks`
# --> 465 return backend.compile(built_c, compile_options=options)
#
# XlaRuntimeError: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.

# %%
# fig, ax = plt.subplots(1, no_scales+2, figsize=(22, 10)) 
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("The error in variance")
moment = 1
plt.errorbar(0, np.mean(moments_target_full[:,moment], axis=0), yerr=np.std(moments_target_full[:,moment], axis=0),color="r", marker="o", label="target")
plt.errorbar(0, np.mean(moments_hybridated_full[:,moment], axis=0), yerr=np.std(moments_hybridated_full[:,moment], axis=0), color='blue', marker="x", alpha=0.5, label="hybridated")

for scale in range(nscales + 1):
    plt.errorbar(scale+1, np.mean(moments_target_starlet[scale, :,moment], axis=0), yerr=np.std(moments_target_starlet[scale,:,moment], axis=0),color="r", marker="o")
    plt.errorbar(scale+1, np.mean(moments_hybridated_starlet[scale,:,moment], axis=0), yerr=np.std(moments_hybridated_starlet[scale,:,moment], axis=0), color='blue', marker="x", alpha=0.5)
plt.legend()

plt.subplot(1,2,2)
plt.title("The error in s3")
moment = 2
plt.errorbar(0, np.mean(moments_target_full[:,moment], axis=0), yerr=np.std(moments_target_full[:,moment], axis=0),color="r", marker="o", label="target")
plt.errorbar(0, np.mean(moments_hybridated_full[:,moment], axis=0), yerr=np.std(moments_hybridated_full[:,moment], axis=0), color='blue', marker="x", alpha=0.5, label="hybridated")

for scale in range(nscales + 1):
    plt.errorbar(scale+1, np.mean(moments_target_starlet[scale, :,moment], axis=0), yerr=np.std(moments_target_starlet[scale,:,moment], axis=0),color="r", marker="o")
    plt.errorbar(scale+1, np.mean(moments_hybridated_starlet[scale,:,moment], axis=0), yerr=np.std(moments_hybridated_starlet[scale,:,moment], axis=0), color='blue', marker="x", alpha=0.5)
plt.legend()

# %%
moments_target_starlet[1, :,moment]
# Out:
# array([254.2605185 , 251.17931264, 241.76551223, 228.0428989 ,
#        237.27347067, 240.52528577, 257.3034294 , 256.03244742,
#        235.77772832, 238.93841829])
